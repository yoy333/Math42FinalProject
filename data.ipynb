# %%
import pandas as pd

# %%
df = pd.read_csv('data/2024_Wimbledon_featured_matches.csv')
print(df.iloc[0])

# %%
num_matches = df["match_id"].nunique()
print(f"number of matches: {num_matches}\n")

players = pd.Series(df[['player1', 'player2']].values.ravel()).drop_duplicates()
print(f"summary of all players: \n{players.describe()}")

# %%
df[["rally_count", "speed_mph", "p2_break_pt_won"]].mean(numeric_only=True)
